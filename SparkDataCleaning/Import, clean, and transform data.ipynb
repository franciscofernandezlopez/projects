# %% [markdown]
# # This notebook imports and processes data for an agricultural price index

# %% [markdown]
# Instrucciones: hay que cambiar el mes de la base nueva.

# %%
import pyspark.sql.functions as F
from pyspark.sql import Window
import os
import pandas as pd
import numpy as np
import re
import sklearn as skl
import seaborn as sns
import plotly.express as px

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

from datetime import datetime, timedelta, date
from pyspark.sql.types import StructType, StructField, StringType, TimestampType, IntegerType, BooleanType, DoubleType, ArrayType, DateType

from operator import add
from functools import reduce

spark.conf.set("key", "code")
spark.conf.set("key", dbutils.secrets.get(scope = "scope", key = "key"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# This notebook assumes we get parquet files data in a defined folder, structured as follows:
#
# - full_dataset
#   - Folder [COUNTRY_prices_{date}]
#     - COUNTRY_prices_{date}
#
#  Where the date has a consistent date format YYYYmmdd

# %%
raw_path_file = '/mnt/{path}/full_dataset/'
clean_path_file = '/mnt/{path}/clean_data/'

list = dbutils.fs.ls(raw_path_file)
list = [list[x][1].split('_')[1] for x in range(len(list))]
list.sort()

last_date_file = list[-1]
last_date_added = pd.to_datetime(last_date_file)

print(last_date_file, last_date_added)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">20230904/ 2023-09-04 00:00:00
# </div>

# %%
# First and last date of the week
last = last_date_added
first = last_date_added - timedelta(weeks=1)
print(first, last)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2023-08-28 00:00:00 2023-09-04 00:00:00
# </div>

# %% [markdown]
# # New data - processing

# %%
col_names = ["period_date", "store_city", "store_key", "barcode", "item_desc", "total_sales_amount", "total_qty"]
data = spark.read.parquet(raw_path_file + 'Carrefour_' + last_date_file)

data = (data
  .drop_duplicates()
  .select(col_names)
  .withColumn('period_date', F.col('period_date').cast(DateType()))
  .withColumn('store_city', F.regexp_replace(F.col('store_city').cast(StringType()), '\..*$', ''))
  .withColumn('store_key', F.regexp_replace(F.col('store_key').cast(StringType()), '\..*$', ''))
  .withColumn('total_sales_amount', F.col('total_sales_amount').cast(DoubleType()))
  .withColumn('total_qty', F.col('total_qty').cast(DoubleType()))
)

data.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>period_date</th><th>store_city</th><th>store_key</th><th>barcode</th><th>item_desc</th><th>total_sales_amount</th><th>total_qty</th></tr></thead><tbody><tr><td>2023-09-04</td><td>UNKNOWN CITY_KEY</td><td>B654</td><td>50097425</td><td>DOVE DEO ROLL ON ORIGINAL 50ML/DOVE DEO ROLL ON ORIGINAL 50ML</td><td>8.78</td><td>3.0</td></tr><tr><td>2023-09-04</td><td>UNKNOWN CITY_KEY</td><td>1722</td><td>54024502</td><td>REXONA STICK COTON 40ML/REXONA STICK KATOEN 40ML</td><td>6.99</td><td>1.0</td></tr><tr><td>2023-09-04</td><td>UNKNOWN CITY_KEY</td><td>B899</td><td>54024786</td><td>SIGNAL BAD CLASSIC FRESH HARD/SIGNAL TB CLASSIC FRESH HARD</td><td>2.49</td><td>1.0</td></tr><tr><td>2023-09-04</td><td>UNKNOWN CITY_KEY</td><td>1866</td><td>54024786</td><td>SIGNAL BAD CLASSIC FRESH HARD/SIGNAL TB CLASSIC FRESH HARD</td><td>2.49</td><td>1.0</td></tr><tr><td>2023-09-04</td><td>UNKNOWN CITY_KEY</td><td>B406</td><td>54024786</td><td>SIGNAL BAD CLASSIC FRESH HARD/SIGNAL TB CLASSIC FRESH HARD</td><td>5.36</td><td>2.0</td></tr><tr><td>2023-09-04</td><td>UNKNOWN CITY_KEY</td><td>B284</td><td>54024878</td><td>SIGNAL BD EXP.COMF MED/SIGNAL TB EXP.COMF MED</td><td>3.69</td><td>1.0</td></tr><tr><td>2023-09-04</td><td>UNKNOWN CITY_KEY</td><td>B468</td><td>54024878</td><td>SIGNAL BD EXP.COMF MED/SIGNAL TB EXP.COMF MED</td><td>4.29</td><td>1.0</td></tr><tr><td>2023-09-04</td><td>UNKNOWN CITY_KEY</td><td>B062</td><td>59082903</td><td>REXONA ROLL CLEAN SENT 50ML/REXONA ROLL CLEAN SENT 50ML</td><td>4.05</td><td>1.0</td></tr><tr><td>2023-09-04</td><td>UNKNOWN CITY_KEY</td><td>B598</td><td>59085744</td><td>REXONA FM INTENSE SPORT 100ML/REXONA FM INTENSE SPORT 100ML</td><td>7.59</td><td>1.0</td></tr><tr><td>2023-09-04</td><td>UNKNOWN CITY_KEY</td><td>B719</td><td>73103714</td><td>REXONA ST.COBALT BLUE 50ML/REXONA ST.COBALT BLUE 50ML</td><td>4.35</td><td>1.0</td></tr></tbody></table></div>

# %% [markdown]
# # Data cleaning, deduplication and outlier detection

# %%
max_date = data.agg(F.max("period_date")).collect()[0][0]
print(max_date)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2023-09-04
# </div>

# %%
data = (data
        .filter(F.col('period_date') >= first)
        .filter(F.col('period_date') <= last))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### IQR

# %%
iqr = (
  data
  .withColumn('log_quantity', F.log(F.col('total_sales_amount') + 0.001))
  .groupBy(['period_date', 'barcode'])
  .agg(F.percentile_approx('log_quantity', 0.25, 10000).alias('IQR_1'), F.percentile_approx('log_quantity', 0.75, 10000).alias('IQR_3'))
  .withColumn('LB', F.col('IQR_1') - 3 * (F.col('IQR_3') - F.col('IQR_1')))
  .withColumn('UB', F.col('IQR_3') + 3 * (F.col('IQR_3') - F.col('IQR_1')))
)

data = (data
        .join(iqr, on = ['period_date', 'barcode'], how = 'left')
        .withColumn('log_quantity', F.log(F.col('total_sales_amount') + 0.1))
        .filter(F.col('log_quantity') >= F.col('LB'))
        .filter(F.col('log_quantity') <= F.col('UB'))
      )

data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>period_date</th><th>barcode</th><th>store_city</th><th>store_key</th><th>item_desc</th><th>total_sales_amount</th><th>total_qty</th><th>IQR_1</th><th>IQR_3</th><th>LB</th><th>UB</th><th>log_quantity</th></tr></thead><tbody><tr><td>2023-09-04</td><td>50097425</td><td>UNKNOWN CITY_KEY</td><td>B654</td><td>DOVE DEO ROLL ON ORIGINAL 50ML/DOVE DEO ROLL ON ORIGINAL 50ML</td><td>8.78</td><td>3.0</td><td>1.1154694057345325</td><td>2.339013449607597</td><td>-2.555162725884661</td><td>6.00964558122679</td><td>2.1838015570040787</td></tr><tr><td>2023-09-04</td><td>54024502</td><td>UNKNOWN CITY_KEY</td><td>1722</td><td>REXONA STICK COTON 40ML/REXONA STICK KATOEN 40ML</td><td>6.99</td><td>1.0</td><td>1.9446236075298482</td><td>2.646245716855093</td><td>-0.16024272044588628</td><td>4.751112044830828</td><td>1.958685340544036</td></tr><tr><td>2023-09-04</td><td>54024786</td><td>UNKNOWN CITY_KEY</td><td>B899</td><td>SIGNAL BAD CLASSIC FRESH HARD/SIGNAL TB CLASSIC FRESH HARD</td><td>2.49</td><td>1.0</td><td>0.9126842362800434</td><td>2.2865573319168484</td><td>-3.208935050630372</td><td>6.408176618827264</td><td>0.9516578757114464</td></tr><tr><td>2023-09-04</td><td>54024786</td><td>UNKNOWN CITY_KEY</td><td>1866</td><td>SIGNAL BAD CLASSIC FRESH HARD/SIGNAL TB CLASSIC FRESH HARD</td><td>2.49</td><td>1.0</td><td>0.9126842362800434</td><td>2.2865573319168484</td><td>-3.208